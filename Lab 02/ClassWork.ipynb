# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
list1 = ['physics', 'chemistry', 1997, 2000];
list2 = [1, 2, 3, 4, 5 ];
list3 = ["a", "b", "c", "d"];

# %%
list1 = ['physics', 'chemistry', 1997, 2000]
list2 = [1, 2, 3, 4, 5, 6, 7 ]

print ("list1[0]: ", list1[0])
print ("list2[1:5]: ", list2[1:5])
# Out:
# list1[0]:  physics
# list2[1:5]:  [2, 3, 4, 5]

# %%
n = np.array([2,3,4,5])
type(n)
# Out:
# numpy.ndarray

# %%
x = np.arange(10)
y = x*2

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
plt.bar(x,y,color='black')
plt.show()

# %%
sns.barplot(x,y,cmap)

# %%
import seaborn as sns
corr = x.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap='hot', square=True)

# %%
# open('iris.csv','wb')

# %%
df= pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
y = df['species']
x = df.drop('species',1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
one = LabelEncoder()
y = one.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=120)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr.score(X_test, y_test)
# Out:
# 0.95744747682056608

# %%
dis = pd.read_clipboard()

# %%
import matplotlib.cm as cm

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.sort_values('petal_length').head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 22           4.6          3.6           1.0          0.2  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 35           5.0          3.2           1.2          0.2  setosa
# 36           5.5          3.5           1.3          0.2  setosa

# %%
df.groupby(['species'][0:4])['sepal_length','sepal_width','petal_length','petal_width'].mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
sepal_length=df['sepal_length']
sepal_width= df['sepal_width']
petal_length = df['sepal_width']
petal_width = df['petal_width']
species = df['species']

# %%
plt.subplot(211)
plt.scatter(sepal_length,sepal_width,c='r', cmap=pylab.cm.cool)
plt.subplot(212)
plt.scatter(petal_length,petal_width,c='g', cmap=pylab.cm.cool)

# %%
colors = cm.rainbow(np.linspace(0, 1, len(species)))
for y, c in zip(species, colors):
    plt.scatter(y, petal_width, color=c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-286-d3eee6c43361> in <module>()
#       1 colors = cm.rainbow(np.linspace(0, 1, len(species)))
#       2 for y, c in zip(species, colors):
# ----> 3     plt.scatter(y, petal_width, color=c)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
df['sepal_width'].mean()
# Out:
# 3.0540000000000007
